# %%
import pandas as pd 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='white')
sns.color_palette('pastel', as_cmap=True)
# Out:
# ['#A1C9F4',
#  '#FFB482',
#  '#8DE5A1',
#  '#FF9F9B',
#  '#D0BBFF',
#  '#DEBB9B',
#  '#FAB0E4',
#  '#CFCFCF',
#  '#FFFEA3',
#  '#B9F2F0']

# %%
df_of_songs = pd.read_csv('data songs/data.csv')
df_of_artist = pd.read_csv('data songs/data_by_artist.csv')

df_of_genres = pd.read_csv('data songs/data_by_genres.csv')

df_of_year = pd.read_csv('data songs/data_by_year.csv')

df_of_artist_genres = pd.read_csv('data songs/data_w_genres.csv')

# %%
df_of_songs
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# ...

# %%
df_of_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %%
print(df_of_songs.shape)
df_of_songs.describe()
# Out:
# (174389, 19)
#         acousticness   danceability   duration_ms         energy  \
# count  174389.000000  174389.000000  1.743890e+05  174389.000000
# mean        0.499228       0.536758  2.328100e+05       0.482721
# std         0.379936       0.176025  1.483958e+05       0.272685
# min         0.000000       0.000000  4.937000e+03       0.000000
# 25%         0.087700       0.414000  1.661330e+05       0.249000
# 50%         0.517000       0.548000  2.057870e+05       0.465000
# 75%         0.895000       0.669000  2.657200e+05       0.711000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  174389.000000     174389.000000  174389.000000  174389.000000
# mean        0.068135          0.197252       5.205305       0.211123
# std         0.251978          0.334574       3.518292       0.180493
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
corr = df_of_songs[['acousticness','danceability','duration_ms','energy','explicit','instrumentalness','key','liveness','loudness','mode','popularity','speechiness','tempo','valence','year']].corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df_of_songs[['acousticness','danceability','duration_ms','energy','explicit','instrumentalness','key','liveness','loudness','mode','popularity','speechiness','tempo','valence','year']].corr(), annot=True, fmt='.1g', vmin=-1, vmax=1, center= 0, cmap=cmap)
plt.show()

# %%
df_numbers = df_of_songs[['acousticness','danceability','duration_ms','energy','explicit','instrumentalness','key','liveness','loudness','mode','popularity','speechiness','tempo','valence','year']]


corr_mat = df_numbers.corr()
corr_pairs = corr_mat.unstack()
pos_corr = corr_pairs[(corr_pairs >= 0.5) & (corr_pairs < 1)]
print("Strong Positive Correlation is observed in the following pairs: \n", pos_corr)

neg_corr = corr_pairs[(corr_pairs <= -0.5) & (corr_pairs > -1)]
print("\nStrong Negative Correlation is observed in the following pairs: \n", neg_corr)
# Out:
# Strong Positive Correlation is observed in the following pairs:
#  danceability  valence         0.536713
# energy        loudness        0.779267
#               year            0.540850
# loudness      energy          0.779267
# popularity    year            0.513227
# valence       danceability    0.536713
# year          energy          0.540850
#               popularity      0.513227
# dtype: float64
#
# Strong Negative Correlation is observed in the following pairs:
#  acousticness  energy         -0.750852
#               loudness       -0.546639
#               year           -0.607515
# energy        acousticness   -0.750852
# loudness      acousticness   -0.546639
# year          acousticness   -0.607515
# dtype: float64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
newdf = df_numbers.select_dtypes(include=numerics)
l = newdf.columns.values
len(l)
# Out:
# 15

# %%
# Boxplots for features 



fig, axes = plt.subplots(3,5, figsize = (13,10))
a=0
for name in l:
    i,j = divmod(a, 5)
    sns.boxplot(y = newdf[name], ax = axes[i,j], color='blue', showfliers=True)
    plt.ylim(newdf[name].min(),newdf[name].max())
    a += 1   

plt.tight_layout()
plt.show()

# %%
sns.histplot(df_numbers['popularity'], bins='auto')
# Out:
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='popularity', ylabel='Count'>

# %%
fig, axes = plt.subplots(3,5, figsize = (13,10))
a=0
for name in l:
    i,j = divmod(a, 5)
    sns.histplot(x = df_numbers[name],ax = axes[i,j] , bins='auto' , color = 'red')
    plt.ylim(newdf[name].min(),newdf[name].max())
    a += 1

plt.tight_layout()
plt.show()
# Out:
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import pandas as pd
from collections import Counter

df_of_songs['artists'] = df_of_songs['artists'].astype(str)

df_of_songs['artists'] = df_of_songs['artists'].str.replace("[",'').str.replace("]",'').str.replace("'",'').str.replace('"','')

df_of_songs['artists'] = df_of_songs['artists'].str.lower()

df_exploded = df_of_songs.assign(artists = df_of_songs['artists'].str.split(',')).explode('artists')

df_exploded['artists'] = df_exploded['artists'].str.strip()

artist_song_count = df_exploded['artists'].value_counts()

df_artist_song_count = pd.DataFrame({'Artist':artist_song_count.index, 'Song_Count':artist_song_count.values})

# %%
df_artist_song_count
# Out:
#                          Artist  Song_Count
# 0              francisco canaro        2228
# 1      tadeusz dolega mostowicz        1281
# 2              эрнест хемингуэй        1175
# 3             эрих мария ремарк        1062
# 4               frédéric chopin        1013
# ...                         ...         ...
# 32621                 dj pierre           1
# 32622                   felicia           1
# 32623                     javah           1
# 32624                       xan           1
# 32625               royal rosss           1
#
# [32626 rows x 2 columns]

# %%
df2 = df_of_songs.copy()

# %%
df2
# Out:
#         acousticness                     artists  danceability  duration_ms  \
# 0           0.991000                 mamie smith         0.598       168333
# 1           0.643000        screamin jay hawkins         0.852       150200
# 2           0.993000                 mamie smith         0.647       163827
# 3           0.000173             oscar velazquez         0.730       422087
# 4           0.295000                        mixe         0.704       165224
# ...              ...                         ...           ...          ...
# 174384      0.009170  dj combo, sander-7, tony t         0.792       147615
# 174385      0.795000                alessia cara         0.429       144720
# 174386      0.806000                   roger fly         0.671       218147
# 174387      0.920000                taylor swift         0.462       244000
# 174388      0.239000                   roger fly         0.677       197710
#
# ...

# %%
sns.lineplot(data=df2, x='year', y='instrumentalness')
# Out:
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='instrumentalness'>

# %%
import matplotlib.pyplot as plt

# Define the number of rows and columns for the subplot grid
num_rows = 3
num_cols = 5

# Create a figure and axis objects for the subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, 20))

# Flatten the axis objects array for easier iteration
axs = axs.flatten()

# Iterate through each column in df_numbers and plot on the corresponding axis
for i, col in enumerate(df_numbers.columns):
    sns.lineplot(data=df2, x='year', y=col, ax=axs[i])
    axs[i].set_title(col)  # Set title for each subplot

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/vijayramaraju/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
